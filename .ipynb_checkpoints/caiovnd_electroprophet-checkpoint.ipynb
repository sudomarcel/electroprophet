# %% [markdown]
# # Electroprophet⚡️

# %% [markdown]
# In this notebook, I will do the first steps on our final project for Le Wagon's Data Science bootcamp. Here, I'll try to model the carbon emission in France using weather data, in order to provide recomendations for users to reduce their carbon footprint 👣.

# %% [markdown]
# ## Getting the data

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### 1. Wheater API

# %% [markdown]
# Here we'll be able to get weather data of a chosen city.

# %% [markdown]
# As the energy data is given by region, later we'll have to check how many cities we have to take in consideration in order to get the weather in a given region.

# %%
import requests
import datetime
from dateutil.relativedelta import relativedelta
import pandas as pd
import os.path

# Get the absolute path of the directory where the script is located
script_dir = os.getcwd()

# Construct the path to the "my_directory" directory relative to the script directory
raw_data_path = os.path.join(script_dir, "raw_data")

# %%
def get_weather(city, years=10, overwrite=False):
    
    '''
    This function receives the name of a city and a number of years, and returns a dataframe 
    with weather data from this city during those past years
    '''
    
    path = raw_data_path + '/df_' + city.lower() + '_weather.csv'
    file_exists = os.path.isfile(path) 
    
    if file_exists and not overwrite:
        
        print('Found a file for this city. Importing...')
        
        weather_df = pd.read_csv(path, index_col=0)
        
    else:
        
        print('Creating a new .csv file for this city')
        
        # First we declare the weather parameters. Here we'll be taking all params supported by the API
        weather_params = ['temperature_2m','relativehumidity_2m','dewpoint_2m',
                      'apparent_temperature','pressure_msl','surface_pressure',
                      'precipitation','rain','snowfall','cloudcover',
                      'cloudcover_low','cloudcover_mid','cloudcover_high',
                      'shortwave_radiation','direct_radiation','direct_normal_irradiance',
                      'diffuse_radiation','windspeed_10m','windspeed_100m',
                      'winddirection_10m','winddirection_100m','windgusts_10m',
                      'et0_fao_evapotranspiration','weathercode','vapor_pressure_deficit',
                      'soil_temperature_0_to_7cm','soil_temperature_7_to_28cm',
                      'soil_temperature_28_to_100cm','soil_temperature_100_to_255cm',
                      'soil_moisture_0_to_7cm','soil_moisture_7_to_28cm',
                      'soil_moisture_28_to_100cm','soil_moisture_100_to_255cm']

        # This request is done in order to get the latitude and longitude of the desired city
        city_response = requests.get('https://geocoding-api.open-meteo.com/v1/search',
                           params = {'name': city}).json()

        lat = city_response['results'][0]['latitude']
        lon = city_response['results'][0]['longitude']

        # Then we compute the dates used to get the weather data
        ## The API only has data until 9 days ago
        end_date = (datetime.date.today() - relativedelta(days=8)).strftime('%Y-%m-%d') 
        #start_date = (datetime.date.today() - relativedelta(years=years)).strftime('%Y-%m-%d')
        start_date = '2013-01-01'

        # So we make the request to the weather API archive
        weather_response = requests.get('https://archive-api.open-meteo.com/v1/archive',
                           params = {'latitude': lat,
                                    'longitude': lon,
                                    'start_date': start_date,
                                    'end_date': end_date,
                                    'hourly': weather_params,
                                    'timezone': 'auto'}).json()
        
        weather_df = pd.DataFrame(weather_response['hourly'], columns = ['time'] + weather_params)
        weather_df['time'] = pd.to_datetime(weather_df['time'], format='%Y-%m-%d')
        weather_df = weather_df.set_index('time')
        
        weather_df.to_csv(path)
    
    print('Done ✅')
    return weather_df

# %%
from prophecy import data

data.get_weather('Amiens')
#df = data.get_weather('Paris',overwrite=True)
#df = data.get_weather('Marseille',overwrite=True)
# Out:
# /home/caiodamasceno/code/Johnny4good/electroprophet/raw_data/df_amiens_weather.csv
# Found a file for Amiens. Importing...
# Done ✅
#                      temperature_2m  relativehumidity_2m  dewpoint_2m  \
# time
# 2013-01-01 00:00:00             8.5                   87          6.4
# 2013-01-01 01:00:00             8.3                   88          6.4
# 2013-01-01 02:00:00             8.3                   89          6.7
# 2013-01-01 03:00:00             8.3                   92          7.0
# 2013-01-01 04:00:00             8.3                   92          7.2
# ...                             ...                  ...          ...
# 2021-08-09 07:00:00            14.3                   86         11.9
# 2021-08-09 08:00:00            15.1                   92         13.8
# 2021-08-09 09:00:00            15.7                   91         14.2
# 2021-08-09 10:00:00            16.5                   90         14.9
# 2021-08-09 11:00:00            18.0                   86         15.7
#
#                      apparent_temperature  pressure_msl  surface_pressure  \
# time
# 2013-01-01 00:00:00                   3.5        1003.8             990.8
# 2013-01-01 01:00:00                   3.8        1003.3             990.3
# 2013-01-01 02:00:00                   4.5        1002.9             989.9
# 2013-01-01 03:00:00                   5.1        1002.6             989.6
# 2013-01-01 04:00:00                   5.3        1002.8             989.8
# ...                                   ...           ...               ...
# 2021-08-09 07:00:00                  13.1        1014.5            1001.6
# 2021-08-09 08:00:00                  13.8        1014.9            1002.0
# 2021-08-09 09:00:00                  13.9        1015.0            1002.1
# 2021-08-09 10:00:00                  15.5        1015.2            1002.4
# 2021-08-09 11:00:00                  17.4        1015.1            1002.4
#
#                      precipitation  rain  snowfall  cloudcover  ...  \
# time                                                            ...
# 2013-01-01 00:00:00            0.9   0.9       0.0         100  ...
# 2013-01-01 01:00:00            0.7   0.7       0.0         100  ...
# 2013-01-01 02:00:00            0.6   0.6       0.0         100  ...
# 2013-01-01 03:00:00            0.5   0.5       0.0         100  ...
# 2013-01-01 04:00:00            0.7   0.7       0.0         100  ...
# ...                            ...   ...       ...         ...  ...
# 2021-08-09 07:00:00            0.2   0.2       0.0         100  ...
# 2021-08-09 08:00:00            0.8   0.8       0.0         100  ...
# 2021-08-09 09:00:00            0.4   0.4       0.0         100  ...
# 2021-08-09 10:00:00            0.1   0.1       0.0          98  ...
# 2021-08-09 11:00:00            0.2   0.2       0.0          40  ...
#
#                      weathercode  vapor_pressure_deficit  \
# time
# 2013-01-01 00:00:00           53                    0.15
# 2013-01-01 01:00:00           53                    0.13
# 2013-01-01 02:00:00           53                    0.12
# 2013-01-01 03:00:00           53                    0.09
# 2013-01-01 04:00:00           53                    0.08
# ...                          ...                     ...
# 2021-08-09 07:00:00           51                    0.23
# 2021-08-09 08:00:00           53                    0.13
# 2021-08-09 09:00:00           51                    0.16
# 2021-08-09 10:00:00           51                    0.18
# 2021-08-09 11:00:00           51                    0.28
#
#                      soil_temperature_0_to_7cm  soil_temperature_7_to_28cm  \
# time
# 2013-01-01 00:00:00                        7.8                         8.1
# 2013-01-01 01:00:00                        7.7                         8.1
# 2013-01-01 02:00:00                        7.7                         8.1
# 2013-01-01 03:00:00                        7.8                         8.1
# 2013-01-01 04:00:00                        7.8                         8.1
# ...                                        ...                         ...
# 2021-08-09 07:00:00                       14.9                        16.2
# 2021-08-09 08:00:00                       15.4                        16.2
# 2021-08-09 09:00:00                       15.8                        16.1
# 2021-08-09 10:00:00                       16.2                        16.2
# 2021-08-09 11:00:00                       17.3                        16.2
#
#                      soil_temperature_28_to_100cm  \
# time
# 2013-01-01 00:00:00                           8.4
# 2013-01-01 01:00:00                           8.4
# 2013-01-01 02:00:00                           8.4
# 2013-01-01 03:00:00                           8.4
# 2013-01-01 04:00:00                           8.4
# ...                                           ...
# 2021-08-09 07:00:00                          16.5
# 2021-08-09 08:00:00                          16.5
# 2021-08-09 09:00:00                          16.5
# 2021-08-09 10:00:00                          16.5
# 2021-08-09 11:00:00                          16.5
#
#                      soil_temperature_100_to_255cm  soil_moisture_0_to_7cm  \
# time
# 2013-01-01 00:00:00                            9.8                   0.430
# 2013-01-01 01:00:00                            9.8                   0.429
# 2013-01-01 02:00:00                            9.8                   0.428
# 2013-01-01 03:00:00                            9.8                   0.428
# 2013-01-01 04:00:00                            9.8                   0.430
# ...                                            ...                     ...
# 2021-08-09 07:00:00                           14.4                   0.376
# 2021-08-09 08:00:00                           14.4                   0.386
# 2021-08-09 09:00:00                           14.4                   0.390
# 2021-08-09 10:00:00                           14.4                   0.390
# 2021-08-09 11:00:00                           14.4                   0.390
#
#                      soil_moisture_7_to_28cm  soil_moisture_28_to_100cm  \
# time
# 2013-01-01 00:00:00                    0.399                      0.407
# 2013-01-01 01:00:00                    0.402                      0.407
# 2013-01-01 02:00:00                    0.404                      0.407
# 2013-01-01 03:00:00                    0.407                      0.407
# 2013-01-01 04:00:00                    0.409                      0.407
# ...                                      ...                        ...
# 2021-08-09 07:00:00                    0.374                      0.315
# 2021-08-09 08:00:00                    0.374                      0.315
# 2021-08-09 09:00:00                    0.374                      0.315
# 2021-08-09 10:00:00                    0.374                      0.315
# 2021-08-09 11:00:00                    0.374                      0.315
#
#                      soil_moisture_100_to_255cm
# time
# 2013-01-01 00:00:00                       0.366
# 2013-01-01 01:00:00                       0.366
# 2013-01-01 02:00:00                       0.366
# 2013-01-01 03:00:00                       0.366
# 2013-01-01 04:00:00                       0.366
# ...                                         ...
# 2021-08-09 07:00:00                       0.355
# 2021-08-09 08:00:00                       0.355
# 2021-08-09 09:00:00                       0.355
# 2021-08-09 10:00:00                       0.355
# 2021-08-09 11:00:00                       0.354
#
# [75420 rows x 33 columns]

# %%
import pandas as pd
pd.to_datetime(df.index, format='%Y-%m-%d')
# Out:
# DatetimeIndex(['2013-03-09 00:00:00', '2013-03-09 01:00:00',
#                '2013-03-09 02:00:00', '2013-03-09 03:00:00',
#                '2013-03-09 04:00:00', '2013-03-09 05:00:00',
#                '2013-03-09 06:00:00', '2013-03-09 07:00:00',
#                '2013-03-09 08:00:00', '2013-03-09 09:00:00',
#                ...
#                '2023-03-01 14:00:00', '2023-03-01 15:00:00',
#                '2023-03-01 16:00:00', '2023-03-01 17:00:00',
#                '2023-03-01 18:00:00', '2023-03-01 19:00:00',
#                '2023-03-01 20:00:00', '2023-03-01 21:00:00',
#                '2023-03-01 22:00:00', '2023-03-01 23:00:00'],
#               dtype='datetime64[ns]', name='time', length=87480, freq=None)

# %%
import datetime

print(datetime.datetime.strptime('2013-01-01','%Y-%m-%d'))
# Out:
# 2013-01-01 00:00:00

# %% [markdown]
# First let's explore and see if we find any problems

# %%
df.duplicated().sum() # Checking for duplicates
# Out:
# 0

# %%
df.isnull().sum().sort_values(ascending=False)/len(df) # Checking for null values

# %%
weather_params = ['temperature_2m','relativehumidity_2m','dewpoint_2m',
                      'apparent_temperature','pressure_msl','surface_pressure',
                      'precipitation','rain','snowfall','cloudcover',
                      'cloudcover_low','cloudcover_mid','cloudcover_high',
                      'shortwave_radiation','direct_radiation','direct_normal_irradiance',
                      'diffuse_radiation','windspeed_10m','windspeed_100m',
                      'winddirection_10m','winddirection_100m','windgusts_10m',
                      'et0_fao_evapotranspiration','weathercode','vapor_pressure_deficit',
                      'soil_temperature_0_to_7cm','soil_temperature_7_to_28cm',
                      'soil_temperature_28_to_100cm','soil_temperature_100_to_255cm',
                      'soil_moisture_0_to_7cm','soil_moisture_7_to_28cm',
                      'soil_moisture_28_to_100cm','soil_moisture_100_to_255cm']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Then we can preprocess our data

# %% [markdown]
# ### 1. MinMax Scaling

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df_preproc = df.copy()
for feature in weather_params:
    scaler.fit(df[[feature]])
    df_preproc[feature] = scaler.transform(df[[feature]])

# %%
df_preproc.head()
# Out:
#                   temperature_2m  relativehumidity_2m  dewpoint_2m  \
# time
# 2013-03-09T00:00        0.409804             0.963855     0.594660
# 2013-03-09T01:00        0.409804             0.963855     0.594660
# 2013-03-09T02:00        0.409804             0.963855     0.594660
# 2013-03-09T03:00        0.409804             0.963855     0.592233
# 2013-03-09T04:00        0.407843             0.963855     0.589806
#
#                   apparent_temperature  pressure_msl  surface_pressure  \
# time
# 2013-03-09T00:00              0.401724      0.381910          0.383929
# 2013-03-09T01:00              0.408621      0.386935          0.389031
# 2013-03-09T02:00              0.415517      0.393216          0.395408
# 2013-03-09T03:00              0.422414      0.395729          0.397959
# 2013-03-09T04:00              0.424138      0.394472          0.396684
#
#                   precipitation  rain  snowfall  cloudcover  ...  weathercode  \
# time                                                         ...
# 2013-03-09T00:00            0.0   0.0       0.0         1.0  ...         0.04
# 2013-03-09T01:00            0.0   0.0       0.0         1.0  ...         0.04
# 2013-03-09T02:00            0.0   0.0       0.0         1.0  ...         0.04
# 2013-03-09T03:00            0.0   0.0       0.0         1.0  ...         0.04
# 2013-03-09T04:00            0.0   0.0       0.0         1.0  ...         0.04
#
#                   vapor_pressure_deficit  soil_temperature_0_to_7cm  \
# time
# 2013-03-09T00:00                0.005525                   0.244737
# 2013-03-09T01:00                0.005525                   0.242105
# 2013-03-09T02:00                0.005525                   0.242105
# 2013-03-09T03:00                0.007366                   0.239474
# 2013-03-09T04:00                0.007366                   0.236842
#
#                   soil_temperature_7_to_28cm  soil_temperature_28_to_100cm  \
# time
# 2013-03-09T00:00                    0.260563                      0.134021
# 2013-03-09T01:00                    0.257042                      0.139175
# 2013-03-09T02:00                    0.257042                      0.139175
# 2013-03-09T03:00                    0.257042                      0.139175
# 2013-03-09T04:00                    0.253521                      0.139175
#
#                   soil_temperature_100_to_255cm  soil_moisture_0_to_7cm  \
# time
# 2013-03-09T00:00                       0.046512                0.863946
# 2013-03-09T01:00                       0.046512                0.857143
# 2013-03-09T02:00                       0.046512                0.853741
# 2013-03-09T03:00                       0.046512                0.846939
# 2013-03-09T04:00                       0.046512                0.840136
#
#                   soil_moisture_7_to_28cm  soil_moisture_28_to_100cm  \
# time
# 2013-03-09T00:00                 0.768421                   0.822785
# 2013-03-09T01:00                 0.771930                   0.822785
# 2013-03-09T02:00                 0.771930                   0.822785
# 2013-03-09T03:00                 0.775439                   0.822785
# 2013-03-09T04:00                 0.775439                   0.822785
#
#                   soil_moisture_100_to_255cm
# time
# 2013-03-09T00:00                    0.917647
# 2013-03-09T01:00                    0.917647
# 2013-03-09T02:00                    0.917647
# 2013-03-09T03:00                    0.917647
# 2013-03-09T04:00                    0.917647
#
# [5 rows x 33 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

index = 0

for index in enumerate(weather_params):
    index=index[0]
    fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(12,3))

    sns.histplot(df[weather_params[index]], bins=200,kde = True, ax=axes[0]);
    sns.boxplot(data=df, x=weather_params[index], ax=axes[1]);
    sns.histplot(df_preproc[weather_params[index]], bins=200,kde = True, ax=axes[2], color='orange');
    sns.boxplot(data=df_preproc, x=weather_params[index], ax=axes[3], color='orange');

# %% [markdown]
# ### 2. Robust Scaler

# %%
from sklearn.preprocessing import RobustScaler


rb_scaler = RobustScaler() 
df_preproc2 = df.copy()
for feature in weather_params:
    rb_scaler.fit(df[[feature]])
    df_preproc2[feature] = rb_scaler.transform(df[[feature]])

rb_scaler.fit(data[['GrLivArea']]) 

data['GrLivArea'] = rb_scaler.transform(data[['GrLivArea']])

# %%
df_weather = data.get_weather('Amiens')
df_weather

# %%
df_merge = data.merge_weather_energy_df('Amiens', 'Hauts-de-France', 'eolien')
df_merge
# Out:
# /home/caiodamasceno/code/Johnny4good/electroprophet/raw_data/df_amiens_weather.csv
# Found a file for Amiens. Importing...
# Done ✅
# Found a file for Hauts-de-France. Importing...

# %%
prod_df = data.get_energy_production(-1, 0, 'Hauts-de-France')
# Out:
# Found a file for Hauts-de-France. Importing...
# Done ✅

# %%
prod_df.columns
# Out:
# Index(['time', 'code_insee_region', 'libelle_region', 'nature', 'date',
#        'heure', 'date_heure', 'consommation', 'thermique', 'nucleaire',
#        'eolien', 'solaire', 'hydraulique', 'pompage', 'bioenergies',
#        'ech_physiques', 'stockage_batterie', 'destockage_batterie',
#        'eolien_terrestre', 'eolien_offshore', 'tco_thermique', 'tch_thermique',
#        'tco_nucleaire', 'tch_nucleaire', 'tco_eolien', 'tch_eolien',
#        'tco_solaire', 'tch_solaire', 'tco_hydraulique', 'tch_hydraulique',
#        'tco_bioenergies', 'tch_bioenergies'],
#       dtype='object')

# %% [markdown]
# ## Baseline model

# %% [markdown]
# First we import our class:

# %%
from prophecy.data_3_cities import WeatherEnergy

# %%
data = WeatherEnergy(limit=-1, offset=0, refine='Hauts-de-France', city1='Heudicourt', city2='Bucy-les-Pierrepont', city3='Riencourt')

# %% [markdown]
# Then we get our dataframe

# %%
df = data.merged()
df.head()
# Out:
#                      temperature_2m  relativehumidity_2m  dewpoint_2m  \
# time
# 2013-03-13 00:00:00            -4.9                 79.0         -8.0
# 2013-03-13 01:00:00            -5.6                 79.0         -8.6
# 2013-03-13 02:00:00            -6.3                 80.0         -9.3
# 2013-03-13 03:00:00            -7.2                 80.0        -10.0
# 2013-03-13 04:00:00            -8.1                 80.0        -10.9
#
#                      apparent_temperature  pressure_msl  surface_pressure  \
# time
# 2013-03-13 00:00:00                 -10.0       1,006.8             992.6
# 2013-03-13 01:00:00                 -10.3       1,006.9             992.7
# 2013-03-13 02:00:00                 -10.4       1,007.2             992.9
# 2013-03-13 03:00:00                 -11.4       1,007.6             993.3
# 2013-03-13 04:00:00                 -12.5       1,007.3             992.9
#
#                      precipitation  rain  snowfall  cloudcover  ...  \
# time                                                            ...
# 2013-03-13 00:00:00            0.0   0.0       0.0        50.0  ...
# 2013-03-13 01:00:00            0.0   0.0       0.0        24.0  ...
# 2013-03-13 02:00:00            0.0   0.0       0.0         9.0  ...
# 2013-03-13 03:00:00            0.0   0.0       0.0         1.0  ...
# 2013-03-13 04:00:00            0.0   0.0       0.0         0.0  ...
#
#                      vapor_pressure_deficit  soil_temperature_0_to_7cm  \
# time
# 2013-03-13 00:00:00                     0.1                        1.0
# 2013-03-13 01:00:00                     0.1                        1.0
# 2013-03-13 02:00:00                     0.1                        1.0
# 2013-03-13 03:00:00                     0.1                        1.0
# 2013-03-13 04:00:00                     0.1                        1.0
#
#                      soil_temperature_7_to_28cm  soil_temperature_28_to_100cm  \
# time
# 2013-03-13 00:00:00                         1.9                           5.1
# 2013-03-13 01:00:00                         1.9                           5.1
# 2013-03-13 02:00:00                         1.9                           5.1
# 2013-03-13 03:00:00                         1.9                           5.0
# 2013-03-13 04:00:00                         1.9                           5.0
#
#                      soil_temperature_100_to_255cm  soil_moisture_0_to_7cm  \
# time
# 2013-03-13 00:00:00                            5.7                     0.4
# 2013-03-13 01:00:00                            5.7                     0.4
# 2013-03-13 02:00:00                            5.7                     0.4
# 2013-03-13 03:00:00                            5.7                     0.4
# 2013-03-13 04:00:00                            5.7                     0.4
#
#                      soil_moisture_7_to_28cm  soil_moisture_28_to_100cm  \
# time
# 2013-03-13 00:00:00                      0.4                        0.4
# 2013-03-13 01:00:00                      0.4                        0.4
# 2013-03-13 02:00:00                      0.4                        0.4
# 2013-03-13 03:00:00                      0.4                        0.4
# 2013-03-13 04:00:00                      0.4                        0.4
#
#                      soil_moisture_100_to_255cm  eolien
# time
# 2013-03-13 00:00:00                         0.4   533.0
# 2013-03-13 01:00:00                         0.4   451.0
# 2013-03-13 02:00:00                         0.4   330.0
# 2013-03-13 03:00:00                         0.4   267.0
# 2013-03-13 04:00:00                         0.4   216.0
#
# [5 rows x 34 columns]

# %% [markdown]
# And we drop all `NaN`'s from our target

# %%
df_nona=df.dropna(subset=['eolien'])

# %% [markdown]
# Now we define our features and target

# %%
X = df_nona.drop(columns=['eolien','weathercode'])
y = df_nona['eolien']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 X = df_nona.drop(columns=['eolien','weathercode'])
#       2 y = df_nona['eolien']
#
# NameError: name 'df_nona' is not defined

# %% [markdown]
# Then we run and evaluate our baseline model with RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# %%
forest = RandomForestRegressor(max_depth=10, n_estimators=100)
score_baseline = cross_val_score(forest, X, y, cv=5,scoring='r2',n_jobs=-1)
score_baseline.mean()
# Out:
# 0.0793604593181183

# %% [markdown]
# Let's try also for XGBoost

# %%
from xgboost import XGBRegressor

# %%
xgb_reg = XGBRegressor(max_depth=10, n_estimators=100, learning_rate=0.1)
score_baseline = cross_val_score(xgb_reg, X, y, cv=5,scoring='r2',n_jobs=-1)
score_baseline.mean()
# Out:
# 0.056958888108195424

# %% [markdown]
# ## Model Tuning

# %%
import numpy as np
import pandas as pd
from random import randint
from sklearn.model_selection import GridSearchCV

# %%
df_scaled = pd.read_csv('raw_data/wind_energy_scaled.csv',index_col=0).dropna(subset=['eolien'])
df_scaled.head()
# Out:
#                      temperature_2m  relativehumidity_2m  dewpoint_2m  \
# time
# 2013-03-13 00:00:00       -2.421369             0.025938    -2.914182
# 2013-03-13 01:00:00       -2.525290             0.025938    -3.027487
# 2013-03-13 02:00:00       -2.629212             0.091235    -3.159676
# 2013-03-13 03:00:00       -2.762825             0.091235    -3.291866
# 2013-03-13 04:00:00       -2.896438             0.091235    -3.461824
#
#                      apparent_temperature  pressure_msl  surface_pressure  \
# time
# 2013-03-13 00:00:00             -2.384180     -1.054767         -1.139810
# 2013-03-13 01:00:00             -2.421353     -1.044193         -1.129068
# 2013-03-13 02:00:00             -2.433744     -1.012471         -1.107584
# 2013-03-13 03:00:00             -2.557652     -0.970175         -1.064616
# 2013-03-13 04:00:00             -2.693952     -1.001897         -1.107584
#
#                      precipitation      rain  snowfall  cloudcover  ...  \
# time                                                                ...
# 2013-03-13 00:00:00      -0.262839 -0.260893 -0.039484   -0.155325  ...
# 2013-03-13 01:00:00      -0.262839 -0.260893 -0.039484   -0.861529  ...
# 2013-03-13 02:00:00      -0.262839 -0.260893 -0.039484   -1.268954  ...
# 2013-03-13 03:00:00      -0.262839 -0.260893 -0.039484   -1.486248  ...
# 2013-03-13 04:00:00      -0.262839 -0.260893 -0.039484   -1.513409  ...
#
#                      vapor_pressure_deficit  soil_temperature_0_to_7cm  \
# time
# 2013-03-13 00:00:00               -0.647985                  -1.651989
# 2013-03-13 01:00:00               -0.670159                  -1.651989
# 2013-03-13 02:00:00               -0.670159                  -1.651989
# 2013-03-13 03:00:00               -0.692333                  -1.651989
# 2013-03-13 04:00:00               -0.692333                  -1.651989
#
#                      soil_temperature_7_to_28cm  soil_temperature_28_to_100cm  \
# time
# 2013-03-13 00:00:00                   -1.732444                     -1.446414
# 2013-03-13 01:00:00                   -1.732444                     -1.446414
# 2013-03-13 02:00:00                   -1.732444                     -1.446414
# 2013-03-13 03:00:00                   -1.732444                     -1.467968
# 2013-03-13 04:00:00                   -1.732444                     -1.467968
#
#                      soil_temperature_100_to_255cm  soil_moisture_0_to_7cm  \
# time
# 2013-03-13 00:00:00                      -1.715239                0.583833
# 2013-03-13 01:00:00                      -1.715239                0.570448
# 2013-03-13 02:00:00                      -1.715239                0.570448
# 2013-03-13 03:00:00                      -1.715239                0.570448
# 2013-03-13 04:00:00                      -1.715239                0.570448
#
#                      soil_moisture_7_to_28cm  soil_moisture_28_to_100cm  \
# time
# 2013-03-13 00:00:00                 0.745491                   1.057895
# 2013-03-13 01:00:00                 0.745491                   1.057895
# 2013-03-13 02:00:00                 0.745491                   1.057895
# 2013-03-13 03:00:00                 0.745491                   1.057895
# 2013-03-13 04:00:00                 0.745491                   1.057895
#
#                      soil_moisture_100_to_255cm  eolien
# time
# 2013-03-13 00:00:00                    1.276617   533.0
# 2013-03-13 01:00:00                    1.276617   451.0
# 2013-03-13 02:00:00                    1.276617   330.0
# 2013-03-13 03:00:00                    1.276617   267.0
# 2013-03-13 04:00:00                    1.276617   216.0
#
# [5 rows x 33 columns]

# %%
X_scaled = df_scaled.drop(columns=['eolien'])
y = df_scaled['eolien']

# %%
forest = RandomForestRegressor(max_depth=10, n_estimators=100)
score_scaled = cross_val_score(forest, X_scaled, y, cv=5,scoring='r2',n_jobs=-1)
score_scaled.mean()
# Out:
# 0.07693815846373371

# %%
grid = {'max_depth': [10,50,100],
        'n_estimators': [10,100,1000]}

# Instantiate Grid Search
forest = RandomForestRegressor()
search = GridSearchCV(forest, grid, 
                            scoring= 'r2',
                            cv=5, n_jobs=-1)

# Fit data to Grid Search
search.fit(X_scaled,y);

print(search.best_params_,search.best_score_)
# Out:
# KeyboardInterrupt

# %% [markdown]
# Fix this tomorrow ☝️

# %% [markdown]
# Don't forget to move this notebook back to the notebooks folder using import sys

# %% [markdown]
# ### Testing Tobias' new file

# %%
! pip install geopy
# Out:
# Collecting geopy
#   Downloading geopy-2.3.0-py3-none-any.whl (119 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.8/119.8 kB 278.0 kB/s eta 0:00:00a 0:00:01
# Collecting geographiclib<3,>=1.52
#   Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 107.9 kB/s eta 0:00:00 0:00:01
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-2.0 geopy-2.3.0

# %%
from prophecy.get_data import WeatherEnergy

# %%
data = WeatherEnergy(limit=-1,
                     offset=0,
                     refine='Hauts-de-France',
                     target = "eolien",
                     city=['Heudicourt', 'Bucy-les-Pierrepont', 'Riencourt'],
                     years=10)

# %%
data.merged()
# Out:
#                      temperature_2m relativehumidity_2m  dewpoint_2m  \
# 2013-03-13 00:00:00            -2.0                27.3         -2.8
# 2013-03-13 00:00:00            -1.4                26.3         -2.4
# 2013-03-13 00:00:00            -1.9                26.3         -2.9
# 2013-03-13 01:00:00            -2.3                27.3         -3.2
# 2013-03-13 01:00:00            -1.5                26.0         -2.6
# ...                             ...                 ...          ...
# 2023-03-05 22:00:00             1.0                29.7          0.5
# 2023-03-05 22:00:00             1.1                27.3          0.2
# 2023-03-05 23:00:00             1.0                28.3          0.3
# 2023-03-05 23:00:00             0.9                30.0          0.4
# 2023-03-05 23:00:00             1.1                27.3          0.2
#
#                      apparent_temperature  pressure_msl  surface_pressure  \
# 2013-03-13 00:00:00                  -3.3         335.9             332.3
# 2013-03-13 00:00:00                  -3.2         335.1             328.9
# 2013-03-13 00:00:00                  -3.5         335.6             332.0
# 2013-03-13 01:00:00                  -3.5         335.9             332.2
# 2013-03-13 01:00:00                  -3.2         335.2             328.9
# ...                                   ...           ...               ...
# 2023-03-05 22:00:00                   0.4         337.6             331.5
# 2023-03-05 22:00:00                   0.3         337.6             334.1
# 2023-03-05 23:00:00                   0.2         337.5             334.0
# 2023-03-05 23:00:00                   0.1         337.4             331.3
# 2023-03-05 23:00:00                   0.3         337.4             334.0
#
#                      precipitation  rain  snowfall cloudcover  ...  \
# 2013-03-13 00:00:00            0.0   0.0       0.0        0.0  ...
# 2013-03-13 00:00:00            0.0   0.0       0.0       27.7  ...
# 2013-03-13 00:00:00            0.0   0.0       0.0        4.3  ...
# 2013-03-13 01:00:00            0.0   0.0       0.0        0.3  ...
# 2013-03-13 01:00:00            0.0   0.0       0.0       20.7  ...
# ...                            ...   ...       ...        ...  ...
# 2023-03-05 22:00:00            0.0   0.0       0.0       33.3  ...
# 2023-03-05 22:00:00            0.0   0.0       0.0       33.3  ...
# 2023-03-05 23:00:00            0.0   0.0       0.0       33.3  ...
# 2023-03-05 23:00:00            0.0   0.0       0.0       33.3  ...
# 2023-03-05 23:00:00            0.0   0.0       0.0       33.3  ...
#
#                     vapor_pressure_deficit soil_temperature_0_to_7cm  \
# 2013-03-13 00:00:00                    0.0                       0.5
# 2013-03-13 00:00:00                    0.0                       0.3
# 2013-03-13 00:00:00                    0.0                       0.5
# 2013-03-13 01:00:00                    0.0                       0.4
# 2013-03-13 01:00:00                    0.0                       0.3
# ...                                    ...                       ...
# 2023-03-05 22:00:00                    0.0                       1.3
# 2023-03-05 22:00:00                    0.0                       1.4
# 2023-03-05 23:00:00                    0.0                       1.4
# 2023-03-05 23:00:00                    0.0                       1.2
# 2023-03-05 23:00:00                    0.0                       1.4
#
#                     soil_temperature_7_to_28cm  soil_temperature_28_to_100cm  \
# 2013-03-13 00:00:00                        0.7                           1.7
# 2013-03-13 00:00:00                        0.7                           1.7
# 2013-03-13 00:00:00                        0.7                           1.7
# 2013-03-13 01:00:00                        0.7                           1.7
# 2013-03-13 01:00:00                        0.7                           1.7
# ...                                        ...                           ...
# 2023-03-05 22:00:00                        1.7                           1.8
# 2023-03-05 22:00:00                        1.7                           1.8
# 2023-03-05 23:00:00                        1.8                           1.8
# 2023-03-05 23:00:00                        1.6                           1.8
# 2023-03-05 23:00:00                        1.7                           1.8
#
#                      soil_temperature_100_to_255cm  soil_moisture_0_to_7cm  \
# 2013-03-13 00:00:00                            1.9                     0.1
# 2013-03-13 00:00:00                            1.8                     0.1
# 2013-03-13 00:00:00                            1.8                     0.1
# 2013-03-13 01:00:00                            1.9                     0.1
# 2013-03-13 01:00:00                            1.8                     0.1
# ...                                            ...                     ...
# 2023-03-05 22:00:00                            2.6                     0.1
# 2023-03-05 22:00:00                            2.5                     0.1
# 2023-03-05 23:00:00                            2.6                     0.1
# 2023-03-05 23:00:00                            2.6                     0.1
# 2023-03-05 23:00:00                            2.5                     0.1
#
#                      soil_moisture_7_to_28cm  soil_moisture_28_to_100cm  \
# 2013-03-13 00:00:00                      0.1                        0.1
# 2013-03-13 00:00:00                      0.1                        0.1
# 2013-03-13 00:00:00                      0.1                        0.1
# 2013-03-13 01:00:00                      0.1                        0.1
# 2013-03-13 01:00:00                      0.1                        0.1
# ...                                      ...                        ...
# 2023-03-05 22:00:00                      0.1                        0.1
# 2023-03-05 22:00:00                      0.1                        0.1
# 2023-03-05 23:00:00                      0.1                        0.1
# 2023-03-05 23:00:00                      0.1                        0.1
# 2023-03-05 23:00:00                      0.1                        0.1
#
#                      soil_moisture_100_to_255cm eolien
# 2013-03-13 00:00:00                         0.1  533.0
# 2013-03-13 00:00:00                         0.1  533.0
# 2013-03-13 00:00:00                         0.1  533.0
# 2013-03-13 01:00:00                         0.1  451.0
# 2013-03-13 01:00:00                         0.1  451.0
# ...                                         ...    ...
# 2023-03-05 22:00:00                         0.1  168.0
# 2023-03-05 22:00:00                         0.1  168.0
# 2023-03-05 23:00:00                         0.1  177.0
# 2023-03-05 23:00:00                         0.1  177.0
# 2023-03-05 23:00:00                         0.1  177.0
#
# [262440 rows x 34 columns]
